# %%
from bs4 import BeautifulSoup
import json
import pandas as pd
from selenium import webdriver
import urllib.parse
import re

# %%
import requests

url = "https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
page_response = requests.get(url)
jsonStr = re.search(r'gon.search=(.*?);', page_response.text).group(1)
print(jsonStr)
jsonObj = json.loads(jsonStr)
print(jsonObj)
records = []
print(jsonObj['schools'][0])

for school in jsonObj['schools']:
    #print(school['name', 'gradeLevels', 'address'])
    try:
            records.append({ 
                        'School': school['name'], 
                        'Rating': school['rating'], 
                        'Rating scale': school['ratingScale'],
                        'Address': school['address']['street1'],
                        'Zip Code': school['address']['zip'], 
                        'Type': school['schoolType'],
                        'Grades': school['gradeLevels'],
                        'Total Students Enrolled': school['enrollment'],
                        'Students per teacher': school['studentsPerTeacher'], 
                        'District': school['districtName'],
                        'URL': school['links']['profile']
                        })
    except KeyError: 
          records.append({ 
                        'School': school['name'], 
                        'Rating': school['rating'], 
                        'Rating scale': school['ratingScale'],
                        'Address': school['address']['street1'],
                        'Zip Code': school['address']['zip'], 
                        'Type': school['schoolType'],
                        'Grades': school['gradeLevels'],
                        'Total Students Enrolled': school['enrollment'],
                        'Students per teacher': 'N/A', 
                        'District': school['districtName'],
                        'URL': school['links']['profile']
                        })
            
            ##print(records)
pd.DataFrame(records).head()
# Out:
# {"schools":[{"id":8798,"districtId":412,"districtName":"Paterson Public School District","districtCity":"Paterson","levelCode":"p","lat":40.916317,"lon":-74.146774,"name":"14# Avenue Early Learning Center","gradeLevels":"PK","assigned":null,"address":{"street1":"660 14th Avenue","street2":null,"zip":"07504","city":"Paterson"},"csaAwardYears":[],"csaGoldAwardYears":[],"thriveAwardYears":[],"rating":null,"ratingScale":null,"schoolType":"public","state":"NJ","zipcode":"07504","type":"school","links":{"profile":"/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/","reviews":"/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/review/","collegeSuccess":"/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/#College_success","schoolImprovement":"/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/#School_improvement","csaState":"/new-jersey/college-success-award"},"highlighted":false,"pinned":null,"testScoreRatingForEthnicity":null,"percentLowIncome":"45%","collegePersistentData":{},"collegeEnrollmentData":{},"score":1.0,"enrollment":77,"parentRating":0,"numReviews":0,"studentsPerTeacher":4,"subratings":{},"ethnicityInfo":[{"label":"Low-income","percentage":45},{"label":"Hispanic","percentage":78},{"label":"African American","percentage":19},{"label":"White","percentage":1},{"label":"Asian or Pacific Islander","percentage":1}],"remediationData":{},"reviewString":"Reviews"},{"id":2215,"districtId":589,"districtName":"Wharton Borough Board Of Education School District","districtCity":"Wharton","levelCode":"m","lat":40.895145,"lon":-74.575897,"name":"A C Mac Kinnon Middle School","gradeLevels":"6-8","assigned":null,"address":{"street1":"137 East Central Avenue","street2":null,"zip":"07885","city":"Wharton"},"csaAwardYears":[],"csaGoldAwardYears":[],"thriveAwardYears":[],"rating":6,"ratingScale":"Average","schoolType":"public","state":"NJ","zipcode":"07885","type":"school","links":{"profile":"/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/","reviews":"/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/#Reviews","collegeSuccess":"/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/#College_success","schoolImprovement":"/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/#School_improvement","csaState":"/new-jersey/college-success-award"},"highlighted":false,"pinned":null,"testScoreRatingForEthnicity":null,"percentLowIncome":"54%","collegePersistentData":{},"collegeEnrollmentData":{},"score":1.0,"enrollment":267,"parentRating":4.2,"numReviews":5,"studentsPerTeacher":8,"subratings":{"Test Scores Rating":6,"Student Progress Rating":7,"Equity Overview Rating":5},"ethnicityInfo":[{"label":"Low-income","rating":5,"percentage":54},{"label":"All students","rating":6},{"label":"Hispanic","rating":5,"percentage":72},{"label":"White","rating":6,"percentage":18},{"label":"Asian or Pacific Islander","percentage":6},{"label":"African American","percentage":3},{"label":"Two or more races","percentage":1},{"label":"Pacific Islander","percentage":1}],"remediationData":{},"reviewString":"Reviews"},{"id":4564,"districtId":418,"districtName":"Pennsauken Township Board Of Education School District","districtCity":"Pennsauken Township","levelCode":"p,e","lat":39.937168,"lon":-75.081581,"name":"A E  Burling Elementary School","gradeLevels":"PK, K-3","assigned":null,"address":{"street1":"3600 HARRIS AVENUE","street2":null,"zip":"08105","city":"PENNSAUKEN"},"csaAwardYears":[],"csaGoldAwardYears":[],"thriveAwardYears":[],"rating":9,"ratingScale":"Above average","schoolType":"public","state":"NJ","zipcode":"08105","type":"school","links":{"profile":"/new-jersey/pennsauken-township/4564-A-E--Burling-Elementary-School/","reviews":"/new-jersey/pennsauken/4564-A-E--Burling-Elementary-School/review/","collegeSuccess":"/new-jersey/pennsauken-township/4564-A-E--Burling-Elementary-School/#College_success","schoolImprovement":"/new-jersey/pennsauken-township/4564-A-E--Burling-Elementary-School/#School_improvement","csaState":"/new-jerse ...
# {'schools': [{'id': 8798, 'districtId': 412, 'districtName': 'Paterson Public School District', 'districtCity': 'Paterson', 'levelCode': 'p', 'lat': 40.916317, 'lon': -74.146774, 'name': '14# Avenue Early Learning Center', 'gradeLevels': 'PK', 'assigned': None, 'address': {'street1': '660 14th Avenue', 'street2': None, 'zip': '07504', 'city': 'Paterson'}, 'csaAwardYears': [], 'csaGoldAwardYears': [], 'thriveAwardYears': [], 'rating': None, 'ratingScale': None, 'schoolType': 'public', 'state': 'NJ', 'zipcode': '07504', 'type': 'school', 'links': {'profile': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/', 'reviews': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/review/', 'collegeSuccess': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/#College_success', 'schoolImprovement': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/#School_improvement', 'csaState': '/new-jersey/college-success-award'}, 'highlighted': False, 'pinned': None, 'testScoreRatingForEthnicity': None, 'percentLowIncome': '45%', 'collegePersistentData': {}, 'collegeEnrollmentData': {}, 'score': 1.0, 'enrollment': 77, 'parentRating': 0, 'numReviews': 0, 'studentsPerTeacher': 4, 'subratings': {}, 'ethnicityInfo': [{'label': 'Low-income', 'percentage': 45}, {'label': 'Hispanic', 'percentage': 78}, {'label': 'African American', 'percentage': 19}, {'label': 'White', 'percentage': 1}, {'label': 'Asian or Pacific Islander', 'percentage': 1}], 'remediationData': {}, 'reviewString': 'Reviews'}, {'id': 2215, 'districtId': 589, 'districtName': 'Wharton Borough Board Of Education School District', 'districtCity': 'Wharton', 'levelCode': 'm', 'lat': 40.895145, 'lon': -74.575897, 'name': 'A C Mac Kinnon Middle School', 'gradeLevels': '6-8', 'assigned': None, 'address': {'street1': '137 East Central Avenue', 'street2': None, 'zip': '07885', 'city': 'Wharton'}, 'csaAwardYears': [], 'csaGoldAwardYears': [], 'thriveAwardYears': [], 'rating': 6, 'ratingScale': 'Average', 'schoolType': 'public', 'state': 'NJ', 'zipcode': '07885', 'type': 'school', 'links': {'profile': '/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/', 'reviews': '/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/#Reviews', 'collegeSuccess': '/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/#College_success', 'schoolImprovement': '/new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle-School/#School_improvement', 'csaState': '/new-jersey/college-success-award'}, 'highlighted': False, 'pinned': None, 'testScoreRatingForEthnicity': None, 'percentLowIncome': '54%', 'collegePersistentData': {}, 'collegeEnrollmentData': {}, 'score': 1.0, 'enrollment': 267, 'parentRating': 4.2, 'numReviews': 5, 'studentsPerTeacher': 8, 'subratings': {'Test Scores Rating': 6, 'Student Progress Rating': 7, 'Equity Overview Rating': 5}, 'ethnicityInfo': [{'label': 'Low-income', 'rating': 5, 'percentage': 54}, {'label': 'All students', 'rating': 6}, {'label': 'Hispanic', 'rating': 5, 'percentage': 72}, {'label': 'White', 'rating': 6, 'percentage': 18}, {'label': 'Asian or Pacific Islander', 'percentage': 6}, {'label': 'African American', 'percentage': 3}, {'label': 'Two or more races', 'percentage': 1}, {'label': 'Pacific Islander', 'percentage': 1}], 'remediationData': {}, 'reviewString': 'Reviews'}, {'id': 4564, 'districtId': 418, 'districtName': 'Pennsauken Township Board Of Education School District', 'districtCity': 'Pennsauken Township', 'levelCode': 'p,e', 'lat': 39.937168, 'lon': -75.081581, 'name': 'A E  Burling Elementary School', 'gradeLevels': 'PK, K-3', 'assigned': None, 'address': {'street1': '3600 HARRIS AVENUE', 'street2': None, 'zip': '08105', 'city': 'PENNSAUKEN'}, 'csaAwardYears': [], 'csaGoldAwardYears': [], 'thriveAwardYears': [], 'rating': 9, 'ratingScale': 'Above average', 'schoolType': 'public', 'state': 'NJ', 'zipcode': '08105', 'type': 'school', 'links': {'profile': '/new-jersey/pennsauken-township/4564-A-E--Burling-Elementary-School/', 'reviews': '/new-jersey/pen ...
# {'id': 8798, 'districtId': 412, 'districtName': 'Paterson Public School District', 'districtCity': 'Paterson', 'levelCode': 'p', 'lat': 40.916317, 'lon': -74.146774, 'name': '14# Avenue Early Learning Center', 'gradeLevels': 'PK', 'assigned': None, 'address': {'street1': '660 14th Avenue', 'street2': None, 'zip': '07504', 'city': 'Paterson'}, 'csaAwardYears': [], 'csaGoldAwardYears': [], 'thriveAwardYears': [], 'rating': None, 'ratingScale': None, 'schoolType': 'public', 'state': 'NJ', 'zipcode': '07504', 'type': 'school', 'links': {'profile': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/', 'reviews': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/review/', 'collegeSuccess': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/#College_success', 'schoolImprovement': '/new-jersey/paterson/8798-14-Avenue-Early-Learning-Center/#School_improvement', 'csaState': '/new-jersey/college-success-award'}, 'highlighted': False, 'pinned': None, 'testScoreRatingForEthnicity': None, 'percentLowIncome': '45%', 'collegePersistentData': {}, 'collegeEnrollmentData': {}, 'score': 1.0, 'enrollment': 77, 'parentRating': 0, 'numReviews': 0, 'studentsPerTeacher': 4, 'subratings': {}, 'ethnicityInfo': [{'label': 'Low-income', 'percentage': 45}, {'label': 'Hispanic', 'percentage': 78}, {'label': 'African American', 'percentage': 19}, {'label': 'White', 'percentage': 1}, {'label': 'Asian or Pacific Islander', 'percentage': 1}], 'remediationData': {}, 'reviewString': 'Reviews'}
#                                  School  Rating   Rating scale  \
# 0      14# Avenue Early Learning Center     NaN           None
# 1          A C Mac Kinnon Middle School     6.0        Average
# 2        A E  Burling Elementary School     9.0  Above average
# 3        A Hamilton Preparatory Academy     6.0        Average
# 4  A. Chester Redshaw Elementary School     2.0  Below average
#
#                    Address Zip Code    Type   Grades  Total Students Enrolled  \
# 0          660 14th Avenue    07504  public       PK                       77
# 1  137 East Central Avenue    07885  public      6-8                      267
# 2       3600 HARRIS AVENUE    08105  public  PK, K-3                      108
# 3        310 Cherry Street    07208  public     9-12                     1000
# 4    216 Livingston Avenue    08901  public  PK, K-5                      824
#
#   Students per teacher                                           District  \
# 0                    4                    Paterson Public School District
# 1                    8  Wharton Borough Board Of Education School Dist...
# 2                   14  Pennsauken Township Board Of Education School ...
# 3                   16                   Elizabeth Public School District
# 4                   12               New Brunswick Public School District
#
#                                                  URL
# 0  /new-jersey/paterson/8798-14-Avenue-Early-Lear...
# 1  /new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle...
# 2  /new-jersey/pennsauken-township/4564-A-E--Burl...
# 3  /new-jersey/elizabeth/7069-A-Hamilton-Preparat...
# 4  /new-jersey/new-brunswick/1296-A.-Chester-Reds...

# %%
df = pd.DataFrame(records)
df.to_csv('./greatschools2.csv', sep=';', encoding='UTF-8', index=False, mode='a')

# %%
fetching = True

page = 0
records = []

while page < 103:  
    page += 1
    url = 'https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"'.format(page)
           
    print("Fetching ", url)

    page_response = requests.get(url)
    jsonStr = re.search(r'gon.search=(.*?);', page_response.text).group(1)
    jsonObj = json.loads(jsonStr)

    for school in jsonObj['schools']:
        #print(school['name', 'gradeLevels', 'address'])
        try:
                records.append({ 
                            'School': school['name'], 
                            'Rating': school['rating'], 
                            'Rating scale': school['ratingScale'],
                            'Address': school['address']['street1'],
                            'Zip Code': school['address']['zip'],
                            'Type': school['schoolType'],
                            'Grades': school['gradeLevels'],
                            'Total Students Enrolled': school['enrollment'],
                            'Students per teacher': school['studentsPerTeacher'], 
                            'District': school['districtName'],
                            'URL': school['links']['profile']
                            })
        except KeyError: 
            records.append({ 
                            'School': school['name'], 
                            'Rating': school['rating'], 
                            'Rating scale': school['ratingScale'],
                            'Address': school['address']['street1'], 
                            'Zip Code': school['address']['zip'],
                            'Type': school['schoolType'],
                            'Grades': school['gradeLevels'],
                            'Total Students Enrolled': school['enrollment'],
                            'Students per teacher': 'N/A', 
                            'District': school['districtName'],
                            'URL': school['links']['profile']
                            })
                
pd.DataFrame(records)
# Out:
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
# Fetching  https://www.greatschools.org/new-jersey/schools/?sort=name&st%5B%5D=public&st%5B%5D=charter&view=table"
#                                          School  Rating   Rating scale  \
# 0              14# Avenue Early Learning Center     NaN           None
# 1                  A C Mac Kinnon Middle School     6.0        Average
# 2                A E  Burling Elementary School     9.0  Above average
# 3                A Hamilton Preparatory Academy     6.0        Average
# 4          A. Chester Redshaw Elementary School     2.0  Below average
# ...                                         ...     ...            ...
# 2570                   Academy For Perform Arts    10.0  Above average
# 2571                Academy For Performing Arts     NaN           None
# 2572            Academy For Urban Leadership Cs     2.0  Below average
# 2573                                  Academy I     9.0  Above average
# 2574  Academy of Career and Technical Education     NaN           None
#
#                       Address Zip Code     Type   Grades  \
# 0             660 14th Avenue    07504   public       PK
# 1     137 East Central Avenue    07885   public      6-8
# 2          3600 HARRIS AVENUE    08105   public  PK, K-3
# 3           310 Cherry Street    07208   public     9-12
# 4       216 Livingston Avenue    08901   public  PK, K-5
# ...                       ...      ...      ...      ...
# 2570        1776 Raritan Road    07076   public     9-12
# 2571           50 Knoll Drive    07866   public     9-12
# 2572         612 Amboy Avenue    08861  charter     7-12
# 2573        209 Bergen Avenue    07305   public      6-8
# 2574        One High Tech Way    07094   public     9-12
#
#       Total Students Enrolled Students per teacher  \
# 0                          77                    4
# 1                         267                    8
# 2                         108                   14
# 3                        1000                   16
# 4                         824                   12
# ...                       ...                  ...
# 2570                      226                   16
# 2571                      122                  N/A
# 2572                      486                   11
# 2573                      432                   15
# 2574                       93                  N/A
#
#                                                District  \
# 0                       Paterson Public School District
# 1     Wharton Borough Board Of Education School Dist...
# 2     Pennsauken Township Board Of Education School ...
# 3                      Elizabeth Public School District
# 4                  New Brunswick Public School District
# ...                                                 ...
# 2570  Union County Vocational-Technical School District
# 2571           Morris County Vocational School District
# 2572                       Academy For Urban Leadership
# 2573                 Jersey City Public School District
# 2574        Hudson County School District Of Technology
#
#                                                     URL
# 0     /new-jersey/paterson/8798-14-Avenue-Early-Lear...
# 1     /new-jersey/wharton/2215-A-C-Mac-Kinnon-Middle...
# 2     /new-jersey/pennsauken-township/4564-A-E--Burl...
# 3     /new-jersey/elizabeth/7069-A-Hamilton-Preparat...
# 4     /new-jersey/new-brunswick/1296-A.-Chester-Reds...
# ...                                                 ...
# 2570  /new-jersey/scotch-plains/6902-Academy-For-Per...
# 2571  /new-jersey/rockaway/8909-Academy-For-Performi...
# 2572  /new-jersey/perth-amboy/7140-Academy-For-Urban...
# 2573  /new-jersey/jersey-city/872-The-Academy-I-Midd...
# 2574  /new-jersey/secaucus/7106-Academy-Of-Career-An...
#
# [2575 rows x 11 columns]

# %%
df = pd.DataFrame(records)
df.to_csv('./greatschools2.csv', sep=';', encoding='UTF-8', index=False, mode='a')
